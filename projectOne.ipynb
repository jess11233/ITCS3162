# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
table = pd.read_csv(r"C:\Users\jesss\OneDrive\Documents\GitHub\ITCS3162\datasets\table_04_28_092021(4-28).csv")

# %%
table.head()
# Out:
#   Table 4-28:  Annual Wasted Fuel Due to Congestion        Unnamed: 1  \
# 0                                        Urban area  Population group
# 1                                               NaN               NaN
# 2                                               NaN               NaN
# 3                                         Akron, OH            Medium
# 4                            Albany-Schenectady, NY            Medium
#
#                   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0  Gallons wasted (millions)        NaN        NaN        NaN        NaN
# 1                        NaN        NaN        NaN        NaN        NaN
# 2                   (R) 1982   (R) 1985   (R) 1990   (R) 1991   (R) 1992
# 3                        0.9        1.4        3.0        3.4        4.2
# 4                        0.6        0.8        1.4        1.5        1.6
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 32 Unnamed: 33 Unnamed: 34  \
# ...

# %%
table.plot(x='urbanarea', y='Populationgroup', kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jesss\miniconda3\envs\classenv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'urbanarea'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ...
